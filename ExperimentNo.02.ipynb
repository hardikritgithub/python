# %%
age=18

# %%
if age>=18:
  print("You are an adult.")

else:
  print("You are not an adult")
# Out:
# You are an adult.

# %%
fruits= ["Apple","Banana","Orange"]
for fruit in fruits:
  print(fruit)
# Out:
# Apple
# Banana
# Orange

# %%
i = 1
while i<=5:
    print(i)
    i+=1
# Out:
# 1
# 2
# 3
# 4
# 5
